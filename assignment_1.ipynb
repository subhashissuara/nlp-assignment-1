# %%
# --------------------------
#   Author: Subhashis Suara
# --------------------------

# Importing the required libraries
import nltk, re, pprint, string
from nltk import word_tokenize, sent_tokenize
from nltk.util import ngrams
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

# Add some other special characters
string.punctuation = string.punctuation +'“'+'”'+'-'+'’'+'‘'+'—'

# Remove periods in order to count the number of sentences
string.punctuation = string.punctuation.replace('.', '')

# Reading corpus: Chapters 20-30 of Pride and Prejudice
corpus = open('corpus.txt', encoding = 'utf8').read()

# Remove chapter headlines 
corpus = re.sub(r'\n|Chapter [20-30]+', '', corpus)

# %%
# Solution to Question 1: Writing Regular Expressions

# Creating corpus variable for 1st question
corpus_q1 = corpus

# Interesting regex patterns
# Long words (longer than 15 characters)
long_words = re.findall(r'\w{15,}', corpus_q1)

# Words with hyphen
hyphenated_words = re.findall(r'\w+-\w+', corpus_q1)

# Words ending with common morphological suffixes, also indicating verbs
morphological_suffixes_words = re.findall(rf'\b\w+ed|\w+ing|\w+ly\b', corpus_q1)

# Patters that indicate proper nouns
proper_nouns = re.findall(r'\b[A-Z][a-z]+\b', corpus_q1)

print("\nLong words (longer than 15 characters): ", long_words)
print("\nHyphenated words: ", hyphenated_words)
print("\nCommon morphological suffixes indicating verb: ", morphological_suffixes_words)
print("\nProper nouns: ", proper_nouns)

# Clean the corpus
# Remove all the punctuations
corpus_q1 = re.sub(r'[^\w\s]', '', corpus_q1)

# Remove all the numbers
corpus_q1 = re.sub(r'\d+', '', corpus_q1)

# Remove all the extra spaces
corpus_q1 = re.sub(r'\s+', ' ', corpus_q1)

# Convert all the words to lower case
corpus_q1 = corpus_q1.lower()

# Tokenize the corpus and mention the counts of top 10 words excluding stop words
tokens = nltk.word_tokenize(corpus_q1)
tokens = [token for token in tokens if token not in stop_words]
fdist = nltk.FreqDist(tokens)
top_10 = fdist.most_common(10)

print("\nTop 10 Words: ", top_10)
# Out:
# Long words (longer than 15 characters):  ['accomplishments', 'congratulations', 'disinterestedness', 'Thoughtlessness', 'recommendations', 'inconsistencies', 'uncompanionable']
#
# Hyphenated words:  ['breakfast-room', 'good-natured', 'breakfast-room', 'ill-humour', 'self-imposed', 'hot-pressed', 'well-educated', 'twenty-seven', 'self-denial', 'leave-taking', 'self-gratulation', 'ill-natured', 'love-making', 'ill-humour', 'good-will', 'narrow-minded', 'well-bred', 'ill-used', 'half-hour', 'ill-natured', 'fellow-creatures', 'ill-natured', 'to-morrow', 'clear-sighted', 'fellow-travellers', 'good-humoured', 'empty-headed', 'twenty-four', 'drawing-room', 'drawing-room', 'to-morrow', 'dining-room', 'dining-room', 'entrance-hall', 'ante-chamber', 'strongly-marked', 'self-importance', 'son-in', 'dinner-time', 'drawing-room', 'last-born', 'one-and', 'card-tables', 'book-room', 'dining-parlour', 'drawing-room', 'card-table', 'half-hours', 'door-bell', 'well-bred']
#
# Common morphological suffixes indicating verb:  ['having', 'dawdled', 'entered', 'congratulated', 'received', 'returned', 'proceeded', 'trusted', 'satisfied', 'steadfastly', 'naturally', 'startled', 'equally', 'satisfied', 'protesting', 'dared', 'saying', 'added', 'directly', 'interrupting', 'cried', 'really', 'naturally', 'actually', 'rejecting', 'accepting', 'alarmed', 'only', 'everything', 'natured', 'lived', 'directly', 'reply', 'hurrying', 'instantly', 'called', 'entered', 'wanted', 'immed', 'iately', 'raised', 'entered', 'fixed', 'altered', 'understanding', 'finished', 'talking', 'marrying', 'called', 'summoned', 'cried', 'appeared', 'replied', 'refused', 'accepting', 'beginning', 'persuaded', 'regarded', 'wished', 'excessively', 'disappointed', 'talking', 'promised', 'marrying', 'replied', 'understanding', 'secondly', 'talked', 'coaxed', 'threatened', 'endeavoured', 'declined', 'interfering', 'replied', 'varied', 'med', 'itating', 'passed', 'suffered', 'deserving', 'prevented', 'feeling', 'family', 'flying', 'cried', 'happened', 'morning', 'hardly', 'joined', 'entered', 'calling', 'entreating', 'comply', 'family', 'added', 'melancholy', 'cruelly', 'used', 'reply', 'spared', 'continued', 'looking', 'unconcerned', 'caring', 'provided', 'refusing', 'talking', 'indeed', 'talking', 'talking', 'pitied', 'listened', 'only', 'talked', 'joined', 'entered', 'stately', 'perceiving', 'passed', 'quietly', 'followed', 'determined', 'detained', 'family', 'satisfied', 'walking', 'pretending', 'projected', 'replied', 'presently', 'continued', 'marked', 'early', 'resigned', 'feeling', 'honoured', 'observed', 'blessing', 'denied', 'showing', 'family', 'withdrawing', 'having', 'requesting', 'having', 'accepted', 'certainly', 'family', 'nearly', 'only', 'feeling', 'necessarily', 'attending', 'occasionally', 'feeling', 'chiefly', 'expressed', 'trying', 'scarcely', 'transferred', 'listening', 'especially', 'produced', 'hoped', 'affected', 'walked', 'returned', 'joined', 'entering', 'attended', 'talked', 'voluntarily', 'acknowledged', 'imposed', 'highly', 'approved', 'civilly', 'bestowed', 'walked', 'during', 'particularly', 'attended', 'accompanying', 'offered', 'introducing', 'delivered', 'contained', 'pressed', 'covered', 'flowing', 'dwelling', 'intently', 'recollected', 'putting', 'tried', 'invited', 'gained', 'taking', 'Bing', 'surprised', 'coming', 'comprised', 'having', 'resolved', 'directly', 'meaning', 'anything', 'unreserved', 'listened', 'surprised', 'nothing', 'really', 'supposed', 'Bing', 'being', 'persuaded', 'Bing', 'renewed', 'Bing', 'detained', 'decided', 'imagined', 'concluded', 'convinced', 'determined', 'following', 'obliged', 'making', 'sincerely', 'generally', 'bring', 'feeling', 'added', 'only', 'Bing', 'doing', 'particularly', 'scarcely', 'really', 'heightened', 'something', 'interesting', 'being', 'mentioned', 'feeling', 'confiding', 'greatly', 'seeing', 'footing', 'misleading', 'engaging', 'nothing', 'indulging', 'finished', 'expressly', 'perfectly', 'convinced', 'feeling', 'kindly', 'totally', 'willing', 'Bing', 'keeping', 'Indeed', 'Bing', 'ordered', 'wed', 'ding', 'achieving', 'certainly', 'succeed', 'seriously', 'Bing', 'greatly', 'being', 'Bing', 'replied', 'wilfully', 'deceiving', 'deceiving', 'started', 'deceived', 'supposing', 'accepting', 'wishing', 'disobliging', 'being', 'faintly', 'smiling', 'exceed', 'ingly', 'grieved', 'being', 'required', 'thing', 'returning', 'treated', 'appeared', 'merely', 'interested', 'openly', 'artfully', 'totally', 'represented', 'forcibly', 'seeing', 'desponding', 'gradually', 'led', 'Bing', 'agreed', 'only', 'family', 'being', 'alarmed', 'bewailed', 'exceed', 'ingly', 'getting', 'lamenting', 'Bing', 'dining', 'invited', 'only', 'family', 'engaged', 'during', 'thanking', 'obliged', 'assured', 'being', 'amply', 'extended', 'nothing', 'engaging', 'parted', 'led', 'morning', 'willing', 'feeling', 'tolerably', 'encouraging', 'comparatively', 'Wed', 'flattering', 'perceived', 'walked ...
#
# Proper nouns:  ['Mr', 'Collins', 'Mrs', 'Bennet', 'Elizabeth', 'Mr', 'Collins', 'This', 'Mrs', 'Bennet', 'But', 'Mr', 'Collins', 'Lizzy', 'She', 'Pardon', 'Mr', 'Collins', 'If', 'Sir', 'Mrs', 'Bennet', 'Lizzy', 'In', 'Mr', 'Bennet', 'She', 'Oh', 'Mr', 'Bennet', 'You', 'Lizzy', 'Mr', 'Collins', 'Mr', 'Bennet', 'Of', 'Of', 'Mr', 'Collins', 'Lizzy', 'Lizzy', 'Mr', 'Collins', 'Mr', 'Collins', 'Lizzy', 'And', 'It', 'Speak', 'Lizzy', 'Tell', 'Let', 'She', 'Mrs', 'Bennet', 'Miss', 'Elizabeth', 'Come', 'Mr', 'Collins', 'Is', 'Elizabeth', 'Very', 'Very', 'We', 'Your', 'Is', 'Mrs', 'Bennet', 'Yes', 'An', 'Elizabeth', 'From', 'Your', 'Mr', 'Collins', 'Elizabeth', 'Mrs', 'Bennet', 'What', 'Mr', 'Bennet', 'You', 'My', 'First', 'Not', 'Mrs', 'Bennet', 'She', 'Elizabeth', 'She', 'Jane', 'Jane', 'Elizabeth', 'Though', 'Mr', 'Collins', 'He', 'His', 'While', 'Charlotte', 'Lucas', 'She', 'Lydia', 'What', 'Mr', 'Collins', 'Lizzy', 'Charlotte', 'Kitty', 'Mrs', 'Bennet', 'Miss', 'Lucas', 'Lizzy', 'Pray', 'Miss', 'Lucas', 'Charlotte', 'Jane', 'Elizabeth', 'Aye', 'Mrs', 'Bennet', 'York', 'But', 'Miss', 'Lizzy', 'Not', 'People', 'Nobody', 'But', 'Those', 'Her', 'She', 'Mr', 'Collins', 'Now', 'Mr', 'Collins', 'Elizabeth', 'Jane', 'Kitty', 'Lydia', 'Charlotte', 'Mr', 'Collins', 'In', 'Mrs', 'Bennet', 'Oh', 'Mr', 'Collins', 'My', 'Far', 'Resignation', 'Perhaps', 'You', 'Mr', 'Bennet', 'My', 'But', 'My', 'The', 'Mr', 'Collins', 'Elizabeth', 'As', 'He', 'Miss', 'Lucas', 'The', 'Mrs', 'Bennet', 'Mr', 'Collins', 'Elizabeth', 'He', 'Saturday', 'Saturday', 'After', 'Meryton', 'Mr', 'Wickham', 'Netherfield', 'He', 'To', 'Elizabeth', 'Mr', 'Darcy', 'She', 'Wickham', 'Longbourn', 'His', 'Soon', 'Miss', 'Bennet', 'Netherfield', 'The', 'Elizabeth', 'Jane', 'Elizabeth', 'Wickham', 'Jane', 'When', 'Jane', 'This', 'Caroline', 'Bingley', 'The', 'Netherfield', 'You', 'She', 'Grosvenor', 'Street', 'Mr', 'Hurst', 'The', 'Hertfordshire', 'To', 'Elizabeth', 'Netherfield', 'Mr', 'Bingley', 'Jane', 'It', 'But', 'Miss', 'Bingley', 'Mr', 'Bingley', 'London', 'Caroline', 'Hertfordshire', 'When', 'London', 'Charles', 'Many', 'Christmas', 'Hertfordshire', 'It', 'Jane', 'It', 'Miss', 'Bingley', 'Why', 'It', 'He', 'But', 'Mr', 'Darcy', 'Georgiana', 'Darcy', 'Louisa', 'My', 'Charles', 'With', 'Jane', 'What', 'Lizzy', 'Jane', 'Is', 'Does', 'Caroline', 'Can', 'Yes', 'Will', 'Most', 'You', 'Miss', 'Bingley', 'Miss', 'Darcy', 'She', 'Jane', 'Indeed', 'Jane', 'No', 'Miss', 'Bingley', 'She', 'Could', 'Mr', 'Darcy', 'But', 'We', 'Miss', 'Darcy', 'Miss', 'Bourgh', 'But', 'Jane', 'Miss', 'Bingley', 'Miss', 'Darcy', 'Tuesday', 'If', 'Miss', 'Bingley', 'Jane', 'But', 'Caroline', 'That', 'You', 'Believe', 'You', 'But', 'You', 'Elizabeth', 'How', 'Jane', 'You', 'But', 'The', 'Elizabeth', 'It', 'Caroline', 'She', 'Jane', 'Bingley', 'Netherfield', 'They', 'Mrs', 'Bennet', 'After', 'Mr', 'Bingley', 'Longbourn', 'The', 'Bennets', 'Lucases', 'Miss', 'Lucas', 'Mr', 'Collins', 'Elizabeth', 'It', 'Charlotte', 'This', 'Charlotte', 'Elizabeth', 'Mr', 'Collins', 'Such', 'Miss', 'Lucas', 'Hertfordshire', 'But', 'Longbourn', 'House', 'Lucas', 'Lodge', 'He', 'Charlotte', 'Wednesday', 'His', 'Miss', 'Lucas', 'But', 'In', 'Mr', 'Collins', 'The', 'Miss', 'Lucas', 'Sir', 'William', 'Lady', 'Lucas', 'Mr', 'Collins', 'Lady', 'Lucas', 'Mr', 'Bennet', 'Sir', 'William', 'Mr', 'Collins', 'Longbourn', 'St', 'James', 'The', 'The', 'Charlotte', 'Charlotte', 'She', 'Her', 'Mr', 'Collins', 'But', 'Without', 'This', 'The', 'Elizabeth', 'Bennet', 'Elizabeth', 'She', 'Mr', 'Collins', 'Longbourn', 'As', 'Mrs', 'Bennet', 'Longbourn', 'My', 'They', 'Mr', 'Bennet', 'But', 'Lady', 'Catherine', 'You', 'My', 'Mr', 'Collins', 'You', 'Risk', 'Believe', 'Hertfordshire', 'As', 'Elizabeth', 'With', 'Mrs', 'Bennet', 'Mary', 'She', 'But', 'Miss', 'Lucas', 'Elizabeth', 'The', 'Mr', 'Collins', 'Elizabeth', 'Charlotte', 'Engaged', 'Mr', 'Collins', 'My', 'Charlotte', 'The', 'Miss', 'Lucas', 'Why', 'Eliza', 'Do', 'Mr', 'Collins', 'But', 'Elizabet ...
#
# Top 10 Words:  [('mr', 123), ('elizabeth', 88), ('could', 85), ('collins', 70), ('would', 70), ('miss', 58), ('mrs', 54), ('jane', 49), ('think', 45), ('bennet', 44)]

# %%
# Solution to Question 3: Language Modelling

# Creating corpus variable for 3rd question
corpus_q3 = ""

# Preprocessing the corpus
for line in corpus:
    # Remove newlines
    line_nl_removed = line.replace("\n", " ")
    corpus_q3 += line_nl_removed

# Remove special characters
corpus_q3 = "".join([char for char in corpus_q3 if char not in string.punctuation])

# Sentence tokenize the corpus
sentences = nltk.sent_tokenize(corpus_q3)
print("Number of sentences: ", len(sentences))

# Word tokenize the corpus
words = nltk.word_tokenize(corpus_q3)
print("Number of tokens: ", len(words)) 

# Average number of tokens per sentence
average_tokens = round(len(words)/len(sentences))
print("Average number of tokens per sentence: ",
average_tokens) 

# Number of unique tokens
unique_tokens = set(words)
print("Number of unique tokens: ", len(unique_tokens)) 

# Create language models
unigram = []
bigram = []
trigram = []
tokenized_text = []

for sentence in sentences:
    sentence = sentence.lower()
    sequence = word_tokenize(sentence) 
    for word in sequence:
        if (word =='.'):
            sequence.remove(word) 
        else:
            unigram.append(word)
    tokenized_text.append(sequence)
    # Create bigrams
    bigram.extend(list(ngrams(sequence, 2)))
    # Create trigrams
    trigram.extend(list(ngrams(sequence, 3)))

# Remove stop words from unigram, bigram and trigram
unigram_stopwords_removed = [word for word in unigram if word not in stop_words]
bigram_stopwords_removed = list(ngrams(unigram_stopwords_removed, 2))
trigram_stopwords_removed = list(ngrams(unigram_stopwords_removed, 3))

# Frequency distribution of unigrams, bigrams and trigrams
fdist_unigram = nltk.FreqDist(unigram_stopwords_removed)
fdist_bigram = nltk.FreqDist(bigram_stopwords_removed)
fdist_trigram = nltk.FreqDist(trigram_stopwords_removed)

# Count of unique unigrams, bigrams and trigrams
unique_unigrams = set(unigram_stopwords_removed)
unique_bigrams = set(bigram_stopwords_removed)
unique_trigrams = set(trigram_stopwords_removed)

print("\nNumber of unique unigrams: ", len(unique_unigrams))
print("Number of unique bigrams: ", len(unique_bigrams))
print("Number of unique trigrams: ", len(unique_trigrams))

# Print top 10 unigrams, bigrams and trigrams
print("\nMost common n-grams with stopword removal: ")

print("\nTop 10 Unigrams: ", fdist_unigram.most_common(10))
print("\nTop 10 Bigrams: ", fdist_bigram.most_common(10))
print("\nTop 10 Trigrams: ", fdist_trigram.most_common(10))

# Applying Add One smoothing
ngrams_all = {1:[], 2:[], 3:[]}

for i in range(3):
    for each in tokenized_text:
        for j in ngrams(each, i + 1):
            ngrams_all[i + 1].append(j)

ngrams_vocabulary = {1:set([]), 2:set([]), 3:set([])}

for i in range(3):
    for gram in ngrams_all[i + 1]:
        if gram not in ngrams_vocabulary[i + 1]:
            ngrams_vocabulary[i + 1].add(gram)

total_ngrams = {1: -1, 2: -1, 3: -1}
total_vocabulary = {1:-1, 2:-1, 3:-1}

for i in range(3):
    total_ngrams[i + 1] = len(ngrams_all[i + 1])
    total_vocabulary[i + 1] = len(ngrams_vocabulary[i + 1])                       
    
ngrams_probabilities = {1:[], 2:[], 3:[]}

for i in range(3):
    for ngram in ngrams_vocabulary[i + 1]:
        temp_list = [ngram]
        temp_list.append(ngrams_all[i + 1].count(ngram))
        ngrams_probabilities[i + 1].append(temp_list)
    
for i in range(3):
    for ngram in ngrams_probabilities[i + 1]:
        ngram[-1] = (ngram[-1] + 1)/(total_ngrams[i + 1] + total_vocabulary[i + 1])

# Print top 10 unigram, bigram, trigram after add one smoothing
print("\nMost common n-grams without stopword removal and with add one smoothing: ")

for i in range(3):
    ngrams_probabilities[i + 1] = sorted(ngrams_probabilities[i + 1], key = lambda x:x[1], reverse = True)
    
print ("\nMost common unigrams: ", str(ngrams_probabilities[1][:10]))
print ("\nMost common bigrams: ", str(ngrams_probabilities[2][:10]))
print ("\nMost common trigrams: ", str(ngrams_probabilities[3][:10]))

# Predict next word
to_predict = "to be"

# Tokenize the sentence
tokens_of_to_predict = nltk.word_tokenize(to_predict)

ngrams_of_to_predict = {1:[], 2:[]}

for i in range(2):
    ngrams_of_to_predict[i + 1] = list(ngrams(tokens_of_to_predict, i + 1))[-1]

for i in range(3):
    ngrams_probabilities[i + 1] = sorted(ngrams_probabilities[i + 1], key = lambda x:x[1], reverse = True)
    
prediction = {1:[], 2:[], 3:[]}

for i in range(2):
    count = 0
    for each in ngrams_probabilities[i + 2]:
        # Find predictions based on highest probability of ngrams
        if each[0][:-1] == ngrams_of_to_predict[i + 1]:
            count += 1
            prediction[i + 1].append(each[0][-1])
            if count == 5:
                break
    if count < 5:
        while(count != 5):
            prediction[i + 1].append("No Prediction")
            count += 1

print(f'\nTop 5 predictions for "{to_predict}" are: ')
print("\nBigram model predictions: ", prediction[1])
print("\nTrigram model predictions: ", prediction[2])
# Out:
# Number of sentences:  551
# Number of tokens:  19320
# Average number of tokens per sentence:  35
# Number of unique tokens:  3063
#
# Number of unique unigrams:  2834
# Number of unique bigrams:  8088
# Number of unique trigrams:  8641
#
# Most common n-grams with stopword removal:
#
# Top 10 Unigrams:  [('mr.', 123), ('elizabeth', 88), ('could', 85), ('collins', 70), ('would', 70), ('miss', 58), ('mrs.', 54), ('jane', 49), ('think', 45), ('bennet', 44)]
#
# Top 10 Bigrams:  [(('mr.', 'collins'), 57), (('lady', 'catherine'), 28), (('mrs.', 'bennet'), 22), (('sir', 'william'), 19), (('mr.', 'darcy'), 15), (('miss', 'lucas'), 13), (('mr.', 'collinss'), 12), (('mr.', 'bennet'), 10), (('miss', 'de'), 10), (('de', 'bourgh'), 10)]
#
# Top 10 Trigrams:  [(('miss', 'de', 'bourgh'), 8), (('mr.', 'darcy', 'would'), 3), (('depend', 'upon', 'mr.'), 2), (('marry', 'mr.', 'collins'), 2), (('insist', 'upon', 'marrying'), 2), (('mr.', 'collins', 'made'), 2), (('collins', 'made', 'offer'), 2), (('could', 'refuse', 'though'), 2), (('dear', 'madam', 'replied'), 2), (('day', 'miss', 'lucas'), 2)]
#
# Most common n-grams without stopword removal and with add one smoothing:
#
# Most common unigrams:  [[('the',), 0.03250310759173151], [('to',), 0.0296026886423277], [('of',), 0.02707057686110216], [('and',), 0.02688642327701303], [('her',), 0.017724782468578795], [('in',), 0.013995672390773905], [('was',), 0.013443211638506515], [('she',), 0.01335113484646195], [('a',), 0.012246213341927168], [('not',), 0.011785829381704341]]
#
# Most common bigrams:  [[('of', 'the'), 0.002604338366189754], [('in', 'the'), 0.0019450121975341202], [('mr.', 'collins'), 0.0019120458891013384], [('to', 'be'), 0.0016483154216390848], [('of', 'her'), 0.0015823828047735215], [('to', 'the'), 0.001417551262609613], [('on', 'the'), 0.0011538207951473595], [('i', 'am'), 0.0011208544867145776], [('it', 'was'), 0.001087888178281796], [('of', 'his'), 0.0010549218698490143]]
#
# Most common trigrams:  [[('mr.', 'collins', 'was'), 0.00032072776044552], [('she', 'could', 'not'), 0.00032072776044552], [('in', 'love', 'with'), 0.0002915706913141091], [('i', 'should', 'be'), 0.0002624136221826982], [('i', 'can', 'not'), 0.0002624136221826982], [('miss', 'de', 'bourgh'), 0.0002624136221826982], [('mr.', 'collins', 'and'), 0.0002624136221826982], [('on', 'the', 'subject'), 0.0002624136221826982], [('out', 'of', 'the'), 0.0002332565530512873], [('i', 'am', 'sure'), 0.0002332565530512873]]
#
# Top 5 predictions for "to be" are:
#
# Bigram model predictions:  ['in', 'very', 'the', 'able', 'happy']
#
# Trigram model predictions:  ['the', 'in', 'kept', 'of', 'done']
